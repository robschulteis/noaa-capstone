# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import re
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
import tarfile
with tarfile.open("C:/Users/robsc/Downloads/202201.tar.gz", "r:*") as tar:
    csv_path = tar.getnames()[0]
    df3 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")

# %%
df.dropna(how='all', axis=1, inplace=True)

# %%
df['SEA_SURF_TEMP'].describe()
# Out:
# count    8922.000000
# mean      232.782000
# std        18.843996
# min       180.000000
# 25%       219.000000
# 50%       238.000000
# 75%       248.000000
# max       278.000000
# Name: SEA_SURF_TEMP, dtype: float64

# %%
df2.dropna(how='all', axis=1, inplace=True)

# %%
df2
# Out:
#       STATION                 DATE  LATITUDE  LONGITUDE  IMMA_VER  ATTM_CT  TIME_IND  LL_IND  ID_IND  WIND_DIR_IND  WIND_DIR  WIND_SPD_IND  WIND_SPEED  VISIBILITY  PRES_WX  SEA_LVL_PRES  IND_FOR_TEMP  SST_MM  SEA_SURF_TEMP  TOT_CLD_AMT CLD_HGT  SWELL_DIR  SWELL_HGT  TEN_BOX_NUM  ONE_BOX_NUM  DECK  SOURCE_ID  PLATFORM_ID  DUP_STATUS  DUP_CHK  NIGHT_DAY_FLAG TRIM_FLAG   NCDC_QC_FLAGS  SOURCE_EXCLUSION_FLAG  STA_WX_IND  IND_FOR_PRECIP
# 0     3401501  2022-02-01T00:00:00    -30.95    -127.13         1        4         2       5      11           NaN       NaN           NaN         NaN         NaN      NaN           NaN             8       9          249.0          NaN     NaN        NaN        NaN          453            7   798        172            7           0      NaN               2    1FFFFF  1AAAAAAAA1AAAA                    4.0         NaN             NaN
# ...

# %%
df3.dropna(how='all', axis=1, inplace=True)

# %%
df3
# Out:
#       STATION                 DATE  LATITUDE  LONGITUDE  IMMA_VER  ATTM_CT  TIME_IND  LL_IND  SHIP_COURSE  SHIP_SPD  ID_IND  WIND_DIR_IND  WIND_DIR  WIND_SPD_IND  WIND_SPEED  VV_IND  VISIBILITY  PRES_WX  PAST_WX  SEA_LVL_PRES  CHAR_PPP  AMT_PRES_TEND  IND_FOR_TEMP  AIR_TEMP  WET_BULB_TEMP  DEW_PT_TEMP  SST_MM  SEA_SURF_TEMP  TOT_CLD_AMT  LOW_CLD_AMT  LOW_CLD_TYPE CLD_HGT  MID_CLD_TYPE HI_CLD_TYPE  WAVE_DIR  WAVE_PERIOD  WAVE_HGT  SWELL_DIR  SWELL_PERIOD  SWELL_HGT  TEN_BOX_NUM  ONE_BOX_NUM  DECK  SOURCE_ID  PLATFORM_ID  DUP_STATUS  DUP_CHK  NIGHT_DAY_FLAG TRIM_FLAG   NCDC_QC_FLAGS  SOURCE_EXCLUSION_FLAG  OB_SOURCE  STA_WX_IND  PAST_WX2  IND_FOR_PRECIP
# ...

# %%
frames = [df, df2, df3]
  
df_2022 = pd.concat(frames)

# %%
df_2022['SEA_SURF_TEMP'].describe()
# Out:
# count    23084.000000
# mean       232.585774
# std         17.032583
# min        180.000000
# 25%        219.000000
# 50%        235.000000
# 75%        247.000000
# max        283.000000
# Name: SEA_SURF_TEMP, dtype: float64

# %%
df_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23546 entries, 0 to 7429
# Data columns (total 55 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   STATION                23546 non-null  object
#  1   DATE                   23546 non-null  object
#  2   LATITUDE               23546 non-null  float64
#  3   LONGITUDE              23546 non-null  float64
#  4   IMMA_VER               23546 non-null  int64
#  5   ATTM_CT                23546 non-null  int64
#  6   TIME_IND               23546 non-null  int64
#  7   LL_IND                 23546 non-null  int64
#  8   SHIP_COURSE            89 non-null     float64
#  9   SHIP_SPD               89 non-null     float64
#  10  ID_IND                 23546 non-null  int64
#  11  WIND_DIR_IND           43 non-null     float64
#  12  WIND_DIR               91 non-null     float64
#  13  WIND_SPD_IND           24 non-null     float64
# ...

# %% [markdown]
# # 2022
# #### (Only 3 months worth of Data)

# %%
i=201
list_of_dfs = []
while i < 204:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2022/202{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2022 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2022 = select_columns(df_2022, selected_columns)
df_2022
# Out:
# ...
#        STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0      3201500  2022-01-01T00:00:00    -35.39    -120.77          208.0
# 1      3201612  2022-01-01T00:00:00    -31.08    -128.49            NaN
# 2      3201638  2022-01-01T00:00:00    -34.66    -128.85          220.0
# 3      3401567  2022-01-01T00:00:00    -31.73    -129.87          226.0
# 4      3401568  2022-01-01T00:00:00    -32.68    -120.51          221.0
# ...        ...                  ...       ...        ...            ...
# 23541  5401586  2022-03-31T23:00:00    -35.89    -123.85          210.0
# 23542  5401664  2022-03-31T23:00:00    -32.88    -124.97          233.0
# 23543  5401685  2022-03-31T23:00:00    -37.93    -127.22          189.0
# 23544  5601511  2022-03-31T23:00:00    -36.34    -125.88          203.0
# 23545  5601512  2022-03-31T23:00:00    -36.87    -124.56          203.0
#
# [23546 rows x 5 columns]

# %% [markdown]
# # 2021

# %%
i=101
list_of_dfs = []
while i < 113:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2021/202{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2021 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2021 = select_columns(df_2021, selected_columns)
df_2021
# Out:
# ...
#        STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0      3201737  2021-01-01T04:00:00    -30.19    -129.82          243.0
# 1      3401571  2021-01-01T04:00:00    -32.03    -125.14          226.0
# 2      3401628  2021-01-01T04:00:00    -31.10    -121.80          237.0
# 3      5401586  2021-01-01T04:00:00    -30.55    -128.97          245.0
# 4      5401673  2021-01-01T04:00:00    -36.13    -129.97          192.0
# ...        ...                  ...       ...        ...            ...
# 56652  3401568  2021-12-31T23:00:00    -32.68    -120.52          221.0
# 56653  3401581  2021-12-31T23:00:00    -32.39    -128.92          229.0
# 56654  3401631  2021-12-31T23:00:00    -32.11    -125.64          226.0
# 56655  5401586  2021-12-31T23:00:00    -30.44    -121.92          235.0
# 56656  5601512  2021-12-31T23:00:00    -35.09    -129.35          218.0
#
# [56657 rows x 5 columns]

# %%
def select_columns(data_frame, column_names):
    new_frame = data_frame.loc[:, column_names]
    return new_frame

# %%
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
new = select_columns(df_2021, selected_columns)

# %% [markdown]
# # 2020

# %%
i=1
list_of_dfs = []
while i < 13:
    with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2020/2020-{i}.tar.gz", "r:*") as tar:
        csv_path = tar.getnames()[0]
        df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
        list_of_dfs.append(pd.DataFrame(df1))
    print(tar)
    i += 1
df_2020 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2020 = select_columns(b, selected_columns)
df_2020
# Out:
# ...
#        STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0
73) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...
#        STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0        48726  2013-01-01T00:00:00     84.27    -134.65            NaN
# 1        48733  2013-01-01T00:00:00     82.48    -136.81            NaN
# 2        48733  2013-01-01T00:10:00     82.48    -136.81            NaN
# 3        48733  2013-01-01T00:20:00     82.47    -136.78            NaN
# 4        48733  2013-01-01T00:30:00     82.47    -136.81            NaN
# ...        ...                  ...       ...        ...            ...
# 131883   48730  2013-12-23T00:00:00     81.18    -139.83            NaN
# 131884   48730  2013-12-23T01:00:00     81.18    -139.86            NaN
# 131885   48730  2013-12-23T02:00:00     81.18    -139.90            NaN
# ...

# %% [markdown]
# # 2012
# #### no sea surface temp column

# %%
i=1
list_of_dfs = []
while i < 13:
    if i < 10:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2012/20120{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
    elif i > 9:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2012/2012{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2012 = pd.concat(list_of_dfs, ignore_index=True)
#selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
#df_2012 = select_columns(df_2012, selected_columns)
df_2012
# Out:
# ...
#       STATION                 DATE  LATITUDE  LONGITUDE  ELEVATION  NAME  IMMA_VER  ATTM_CT  TIME_IND  LL_IND  ID_IND  SEA_LVL_PRES  TEN_BOX_NUM  ONE_BOX_NUM  DECK  SOURCE_ID  PLATFORM_ID  DUP_STATUS  NIGHT_DAY_FLAG TRIM_FLAG   NCDC_QC_FLAGS  SOURCE_EXCLUSION_FLAG  IND_FOR_TEMP  SHIP_COURSE  SHIP_SPD  NAT_SOURCE_IND COUNTRY_CODE  WIND_DIR_IND  WIND_SPD_IND  CHAR_PPP  AMT_PRES_TEND  DPT_IND  DUP_CHK  OB_PLATFORM  IND_FOR_PRECIP  QC_IND QC_IND_FOR_FIELDS  MQCS_VER  AIR_TEMP  EXTERNAL
# 0       48611  2012-01-01T00:00:00     84.17    -136.21        NaN   NaN         1        3         2       5       3       10047.0           20           46   714         63            7           0               1    FFFFBF  1AAAA1AAAAAAAA                    4.0           NaN          NaN       NaN             NaN          NaN           NaN           NaN       NaN            NaN      NaN      NaN          NaN             NaN     NaN               NaN       NaN       NaN       NaN
# ...

# %%
df_2012.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14338 entries, 0 to 14337
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   STATION                14338 non-null  object
#  1   DATE                   14338 non-null  object
#  2   LATITUDE               14338 non-null  float64
#  3   LONGITUDE              14338 non-null  float64
#  4   ELEVATION              0 non-null      float64
#  5   NAME                   0 non-null      float64
#  6   IMMA_VER               14338 non-null  int64
#  7   ATTM_CT                14338 non-null  int64
#  8   TIME_IND               14338 non-null  int64
#  9   LL_IND                 14338 non-null  int64
#  10  ID_IND                 14338 non-null  int64
#  11  SEA_LVL_PRES           7128 non-null   float64
#  12  TEN_BOX_NUM            14338 non-null  int64
#  13  ONE_BOX_NUM            14338 non-null  int64
# ...

# %% [markdown]
# # 2011

# %%
i=1
list_of_dfs = []
while i < 13:
    if i < 10:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2011/20110{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
    elif i > 9:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2011/2011{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': int}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2011 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2011 = select_columns(df_2011, selected_columns)
df_2011
# Out:
# ...
#        STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0        25514  2011-01-01T00:00:00     87.32    -134.22            NaN
# 1        25514  2011-01-01T01:00:00     87.32    -134.24            NaN
# 2        25514  2011-01-01T02:00:00     87.32    -134.26            NaN
# 3        25514  2011-01-01T03:00:00     87.32    -134.30            NaN
# 4        25514  2011-01-01T04:00:00     87.33    -134.24            NaN
# ...        ...                  ...       ...        ...            ...
# 201384   48611  2011-12-31T19:00:00     84.16    -136.52            NaN
# 201385   48611  2011-12-31T20:00:00     84.16    -136.46            NaN
# 201386   48611  2011-12-31T21:00:00     84.16    -136.39            NaN
# 201387   48611  2011-12-31T22:00:00     84.16    -136.33            NaN
# 201388   48611  2011-12-31T23:00:00     84.16    -136.27            NaN
#
# [201389 rows x 5 columns]

# %% [markdown]
# # 2010

# %%
i=1
list_of_dfs = []
while i < 13:
    if i < 10:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2010/20100{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
    elif i > 9:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2010/2010{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2010 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2010 = select_columns(df_2010, selected_columns)
df_2010
# Out:
# ...
# C:\Users\robsc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (67,68,69,70,71) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...
#        STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0        48547  2010-01-28T16:00:00     81.81    -139.96            NaN
# 1        48512  2010-01-28T18:00:00     81.87    -139.98            NaN
# 2        48547  2010-01-28T18:00:00     81.81    -139.96            NaN
# 3         UFTA  2010-01-28T18:00:00     81.90    -140.00            NaN
# 4        48512  2010-01-28T20:00:00     81.87    -139.93            NaN
# ...        ...                  ...       ...        ...            ...
# 389006   25514  2010-12-31T19:00:00     87.32    -134.14            NaN
# 389007   25514  2010-12-31T20:00:00     87.32    -134.15            NaN
# 389008   25514  2010-12-31T21:00:00     87.32    -134.16            NaN
# ...

# %% [markdown]
# # 2009
# #### NO SEA SURFACE TEMPERATURE READINGS

# %%
i=1
list_of_dfs = []
while i < 13:
    if i < 10:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2009/20090{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
    elif i > 9:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2009/2009{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2009 = pd.concat(list_of_dfs, ignore_index=True)
#selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
#df_2009 = select_columns(df_2009, selected_columns)
df_2009
# Out:
# ...
#       STATION                 DATE  LATITUDE  LONGITUDE  ELEVATION  NAME  IMMA_VER  ATTM_CT  TIME_IND  LL_IND  ID_IND  WIND_DIR_IND  WIND_SPD_IND  VISIBILITY  PRES_WX  PAST_WX  SEA_LVL_PRES  CHAR_PPP  AMT_PRES_TEND  IND_FOR_TEMP  AIR_TEMP  TOT_CLD_AMT  LOW_CLD_AMT LOW_CLD_TYPE CLD_HGT MID_CLD_TYPE HI_CLD_TYPE  TEN_BOX_NUM  ONE_BOX_NUM  DECK  SOURCE_ID  PLATFORM_ID  DUP_STATUS  DUP_CHK  NIGHT_DAY_FLAG TRIM_FLAG   NCDC_QC_FLAGS  EXTERNAL  SOURCE_EXCLUSION_FLAG  STA_WX_IND  PAST_WX2  IND_FOR_PRECIP  AMT_PRECIP  DUR_OF_PER  SHIP_COURSE  SHIP_SPD COUNTRY_CODE  VV_IND  IND_FOR_WBT  DPT_IND  SST_MM  HGT_IND  WAVE_PERIOD  WAVE_HGT  SWELL_PERIOD  SWELL_HGT  OB_SOURCE  OB_PLATFORM  FM_CODE_VER  THICKNESS_OF_I  RATE_OF_I  CONCEN_OF_SEA_ICE STAGE_OF_DEVELP ICE_OF_LAND_ORIGIN TRUE_BEARING_ICE_EDGE ICE_SIT_TREND  QC_IND QC_IND_FOR_FIELDS  MQCS_VER  SHIP_HEADING  COURSE_OVER_GROUND  SPD_OVER_GROUND  REL_WIND_DIR  REL_WIND_SPD  ICE_ACCR_ON_SHIP
# ...

# %% [markdown]
# # 2008
# #### NO SEA SURFACE TEMPERATURE DATA

# %%
i=1
list_of_dfs = []
while i < 13:
    if i < 10:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2008/20080{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
    elif i > 9:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2008/2008{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2008 = pd.concat(list_of_dfs, ignore_index=True)
#selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
#df_2008 = select_columns(df_2008, selected_columns)
df_2008
# Out:
# ...
# C:\Users\robsc\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (30,31,32,57,58) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# ...

# %% [markdown]
# # 2007
# #### only 150 sea surface temperature recordings

# %%
i=1
list_of_dfs = []
while i < 13:
    if i < 10:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2007/20070{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
    elif i > 9:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2007/2007{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2007 = pd.concat(list_of_dfs, ignore_index=True)
#selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
#df_2007 = select_columns(df_2007, selected_columns)
df_2007.info()
# Out:
# ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48463 entries, 0 to 48462
# Data columns (total 73 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   STATION                48463 non-null  object
#  1   DATE                   48463 non-null  object
#  2   LATITUDE               48463 non-null  float64
#  3   LONGITUDE              48463 non-null  float64
#  4   ELEVATION              0 non-null      float64
#  5   NAME                   0 non-null      float64
#  6   IMMA_VER               48463 non-null  int64
#  7   ATTM_CT                48463 non-null  int64
#  8   TIME_IND               48406 non-null  float64
#  9   LL_IND                 48406 non-null  float64
#  10  ID_IND                 48463 non-null  int64
#  11  SEA_LVL_PRES           41385 non-null  float64
#  12  IND_FOR_TEMP           37926 non-null  float64
#  13  AIR_TEMP               13335 non-null  float64
# ...

# %% [markdown]
# # 2006

# %%
i=1
list_of_dfs = []
while i < 13:
    if i < 10:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2006/20060{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
    elif i > 9:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2006/2006{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2006 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2006 = select_columns(df_2006, selected_columns)
df_2006
# Out:
# ...
#        STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0        41001  2006-01-01T00:00:00     34.70     -72.70          203.0
# 1        41002  2006-01-01T00:00:00     32.30     -75.40          219.0
# 2        41004  2006-01-01T00:00:00     32.50     -79.10          189.0
# 3        41013  2006-01-01T00:00:00     33.40     -77.70          193.0
# 4        41025  2006-01-01T00:00:00     35.00     -75.40          201.0
# ...        ...                  ...       ...        ...            ...
# 184388   48523  2006-12-31T22:17:00     83.17    -138.62            NaN
# 184389   48523  2006-12-31T22:38:00     83.16    -138.60            NaN
# 184390   48523  2006-12-31T22:58:00     83.16    -138.65            NaN
# 184391   48523  2006-12-31T23:43:00     83.16    -138.62            NaN
# 184392   48523  2006-12-31T23:55:00     83.16    -138.69            NaN
#
# [184393 rows x 5 columns]

# %% [markdown]
# # 2005

# %%
i=501
list_of_dfs = []
while i < 513:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2005/200{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2005 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2005 = select_columns(df_2005, selected_columns)
df_2005
# Out:
# ...
#       STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0       48583  2005-01-04T15:00:00     80.21    -137.36            NaN
# 1       48583  2005-01-04T18:00:00     80.22    -137.35            NaN
# 2       48583  2005-01-04T18:48:00     80.22    -137.35            NaN
# 3       48583  2005-01-04T20:02:00     80.22    -137.35            NaN
# 4       48583  2005-01-04T21:00:00     80.24    -137.34            NaN
# ...       ...                  ...       ...        ...            ...
# 92368   41025  2005-12-31T23:50:00     35.00     -75.40          201.0
# 92369   41035  2005-12-31T23:50:00     34.50     -77.30          109.0
# 92370   44004  2005-12-31T23:50:00     38.50     -70.50          144.0
# 92371   44009  2005-12-31T23:50:00     38.50     -74.70           79.0
# 92372   TYBG1  2005-12-31T23:50:00     31.63     -79.93            NaN
#
# [92373 rows x 5 columns]

# %% [markdown]
# # 2004

# %%
i=401
list_of_dfs = []
while i < 413:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2004/200{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2004 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2004 = select_columns(df_2004, selected_columns)
df_2004
# Out:
# ...
#       STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0       48583  2004-01-15T00:00:00     83.57    -139.82            NaN
# 1       48583  2004-01-15T00:53:00     83.57    -139.82            NaN
# 2       48583  2004-01-15T02:32:00     83.57    -139.82            NaN
# 3       48583  2004-01-15T03:00:00     83.57    -139.76            NaN
# 4       48583  2004-01-15T06:00:00     83.58    -139.71            NaN
# ...       ...                  ...       ...        ...            ...
# 29461   41004  2004-12-31T23:50:00     32.50     -79.10          213.0
# 29462   41013  2004-12-31T23:50:00     33.50     -77.60          212.0
# 29463   44004  2004-12-31T23:50:00     38.50     -70.50          147.0
# 29464   44009  2004-12-31T23:50:00     38.50     -74.70           79.0
# 29465   44014  2004-12-31T23:50:00     36.60     -74.80          114.0
#
# [29466 rows x 5 columns]

# %% [markdown]
# # 2003

# %%
i=301
list_of_dfs = []
while i < 313:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2003/200{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2003 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2003 = select_columns(df_2003, selected_columns)
df_2003
# Out:
# ...
#       STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0       48601  2003-01-01T01:44:00     80.56    -136.49            NaN
# 1       48601  2003-01-01T03:24:00     80.56    -136.52            NaN
# 2       48601  2003-01-01T05:04:00     80.56    -136.54            NaN
# 3       48601  2003-01-01T06:43:00     80.56    -136.58            NaN
# 4       48601  2003-01-01T08:28:00     80.57    -136.59            NaN
# ...       ...                  ...       ...        ...            ...
# 23430   41013  2003-12-31T23:50:00     33.50     -77.60          191.0
# 23431   41025  2003-12-31T23:50:00     35.20     -75.30          163.0
# 23432   44004  2003-12-31T23:50:00     38.50     -70.50          142.0
# 23433   44009  2003-12-31T23:50:00     38.50     -74.70            NaN
# 23434   44014  2003-12-31T23:50:00     36.60     -74.80          125.0
#
# [23435 rows x 5 columns]

# %% [markdown]
# # 2002
# #### no sea serface temperature recordings

# %%
i=201
list_of_dfs = []
while i < 213:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2002/200{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2002 = pd.concat(list_of_dfs, ignore_index=True)
#selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
#df_2002 = select_columns(df_2002, selected_columns)
df_2002
# Out:
# ...
#       STATION                 DATE  LATITUDE  LONGITUDE  ELEVATION  NAME  IMMA_VER  ATTM_CT  TIME_IND  LL_IND  ID_IND  SEA_LVL_PRES  IND_FOR_TEMP  AIR_TEMP  TEN_BOX_NUM  ONE_BOX_NUM  DECK  SOURCE_ID  PLATFORM_ID  DUP_STATUS  NIGHT_DAY_FLAG TRIM_FLAG   NCDC_QC_FLAGS  EXTERNAL  SOURCE_EXCLUSION_FLAG
# 0       25569  2002-01-01T03:00:00     86.25    -132.38        NaN   NaN         1        3         2       5       3           NaN           NaN       NaN           20           62   714         63            7           0               1    FFFFFF  1AAAAAAAAAAAAA       NaN                      4
# 1       25569  2002-01-01T06:00:00     86.25    -132.39        NaN   NaN         1        3         2       5       3        9971.0           NaN       NaN           20           62   714         63            7           0               1    FFFFBF  1AAAA1AAAAAAAA       8.0                      4
# ...

# %% [markdown]
# # 2001

# %%
i=101
list_of_dfs = []
while i < 113:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2001/200{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2001 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2001 = select_columns(df_2001, selected_columns)
df_2001
# Out:
# ...
#       STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0       C6RN9  2001-01-01T00:00:00     34.00     -72.40          210.0
# 1       CHLV2  2001-01-01T00:00:00     36.90     -75.70           64.0
# 2       CLKN7  2001-01-01T00:00:00     34.60     -76.50            NaN
# 3       DSLN7  2001-01-01T00:00:00     35.20     -75.30            NaN
# 4       DUCN7  2001-01-01T00:00:00     36.20     -75.80            NaN
# ...       ...                  ...       ...        ...            ...
# 78115   25569  2001-12-31T09:00:00     86.22    -132.78            NaN
# 78116   25569  2001-12-31T12:00:00     86.22    -132.78            NaN
# 78117   25569  2001-12-31T15:00:00     86.23    -132.53            NaN
# 78118   25569  2001-12-31T18:00:00     86.24    -132.47            NaN
# 78119   25569  2001-12-31T21:00:00     86.25    -132.42            NaN
#
# [78120 rows x 5 columns]

# %%
i=1
list_of_dfs = []
while i < 13:
    if i < 10:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2000/20000{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
    elif i > 9:
        with tarfile.open(f"C:/NSS/Projects/capstone-noaa-pop/data/2000/2000{i}.tar.gz", "r:*") as tar:
            csv_path = tar.getnames()[0]
            df1 = pd.read_csv(tar.extractfile(csv_path), dtype={'SEA_SURF_TEMP': float}, header=0, sep=",")
            list_of_dfs.append(pd.DataFrame(df1))
        print(tar)
        i += 1
df_2000 = pd.concat(list_of_dfs, ignore_index=True)
selected_columns = ['STATION', 'DATE', 'LATITUDE', 'LONGITUDE', 'SEA_SURF_TEMP']
df_2000 = select_columns(df_2000, selected_columns)
df_2000
# Out:
# ...
#       STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0       CHLV2  2000-01-01T00:00:00     36.90     -75.70           81.0
# 1       CLKN7  2000-01-01T00:00:00     34.60     -76.50            NaN
# 2       DSLN7  2000-01-01T00:00:00     35.20     -75.30            NaN
# 3       DUCN7  2000-01-01T00:00:00     36.20     -75.80            NaN
# 4       FPSN7  2000-01-01T00:00:00     33.50     -77.60            NaN
# ...       ...                  ...       ...        ...            ...
# 52009   41002  2000-12-31T23:50:00     32.30     -75.20          214.0
# 52010   41004  2000-12-31T23:50:00     32.50     -79.10          180.0
# 52011   44009  2000-12-31T23:50:00     38.50     -74.70           53.0
# 52012   44014  2000-12-31T23:50:00     36.60     -74.80          152.0
# 52013   41503  2000-12-31T23:55:00     32.25     -75.13          216.0
#
# [52014 rows x 5 columns]

# %%
frames = [df_2022
          , df_2021
          , df_2020
          , df_2019
          , df_2018
          , df_2017
          , df_2016
          , df_2015
          , df_2014
          , df_2013
          , df_2011
          , df_2010
          , df_2006
          , df_2005
          , df_2004
          , df_2003
          , df_2001
          , df_2001]
  
df_2000s = pd.concat(frames)

# %%
df_2000s = df_2000s.reset_index(drop=True)

# %%
df_2000s
# Out:
#          STATION                 DATE  LATITUDE  LONGITUDE  SEA_SURF_TEMP
# 0        3201500  2022-01-01T00:00:00    -35.39    -120.77          208.0
# 1        3201612  2022-01-01T00:00:00    -31.08    -128.49            NaN
# 2        3201638  2022-01-01T00:00:00    -34.66    -128.85          220.0
# 3        3401567  2022-01-01T00:00:00    -31.73    -129.87          226.0
# 4        3401568  2022-01-01T00:00:00    -32.68    -120.51          221.0
# ...          ...                  ...       ...        ...            ...
# 1999235    25569  2001-12-31T09:00:00     86.22    -132.78            NaN
# 1999236    25569  2001-12-31T12:00:00     86.22    -132.78            NaN
# 1999237    25569  2001-12-31T15:00:00     86.23    -132.53            NaN
# 1999238    25569  2001-12-31T18:00:00     86.24    -132.47            NaN
# 1999239    25569  2001-12-31T21:00:00     86.25    -132.42            NaN
#
# [1999240 rows x 5 columns]
